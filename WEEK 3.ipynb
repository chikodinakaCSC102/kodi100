# %% [markdown]
# CHINAKA CHIKODINAKA
# chikodinaka.chinaka@pau.edu.ng
# ### Project 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = float(input("Input number: "))
x = a-17
y= 2 * x
if a>17:
    print(y)
else:
    print(-x)

# %% [markdown]
# ### Project 2
# ![image.png](attachment:image.png)
# INPUT first number(n1)
# INPUT second number(n2)
# INPUT third number(n3)
# COMPUTE (n1 + n2 + n3)= X
# IF n1=n2=n3
# PRINT 3X
# ELSE
# PRINT X

# %%
a = float(input("Input first number: "))
b = float(input("Input second number: "))
c = float(input("Input third number: "))
x = a + b + c
if a==b==c:
    print(3*x)
else:
    print(x)

# %% [markdown]
# ### Project 3
# ![image.png](attachment:image.png)
# INPUT first number
# INPUT second number
# IF first number=second number or
# first number + second number = 5 or
# first number - second number = 5
# PRINT True
# ELSE
# PRINT False

# %%
a = int(input("Input number: "))
b = int(input("Input number: "))
if a==b:
    print("True")
elif a+b==5:
    print("True")
elif a-b==5:
    print("True")
else:
    print("False")

# %% [markdown]
# ### Project 4
# ![image.png](attachment:image.png)
# INPUT first number
# INPUT second number
# INPUT third number
# COMPUTE (n1+n2+n3)- max-min
# PRINT max
# PRINT middle
# PRINT min

# %%
x=int(input("Input number: "))
y=int(input("Input number: "))
z=int(input("Input number: "))
a1=max(x,y,z)
a3=min(x,y,z)
a2=(x+y+z)-a1-a3
print("numbers in sort order:",a1,a2,a3)

# %% [markdown]
# ### Project 5
# ![image.png](attachment:image.png)

# %%
N = int(input("Enter number: "))
num = 0
for i in range(1,N):
    num +=i**3
print(num)
# Out:
# Enter number: 6
# 225
